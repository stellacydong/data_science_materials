# %% [markdown]
# # Objectives:
# 1. introduction matplotlib and pyplot
# 2. plot lines
# 3. change line/marker style
# 4. define the range of the axes and add legend
# 5. add axes title, axis label and line legend
# 6. change the size of the figure
# 7. plot functions
# 8. make subplots
# 9. improve subplot size/spacing with many subplots in matplotlib

# %% [markdown]
# ## What is matplotlib?
# - open-source python library for 2D plotting
# - API inspired by MATLAB
# - some of the available diagram types: plots, histograms, bar charts, scatterplots ...

# %% [markdown]
# ## What is pyplot?
#
# matplotlib.pyplot: is a collection of functions that make matplotlib work like MATLAB
# each pyplot function makes some change to a figure: e.g. create a figure, create a plotting area in a figure, decorate the plot with labels, etc.
#
# reference: https://matplotlib.org/2.0.2/api/pyplot_api.html

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## How to plot lines?

# %%
# define data as lists
x1 = [2,4,6,8]
y1 = [5.5,7,2,4]
x2 = [4,6,8,10,12,14]
y2 = [-12,-14,-7,-12,-3.3,-1]

# %%
#let's draw the first line
# if no x-value is given an incrementing index, beginning from zero, will be used
plt.plot(y1)
plt.show()

# %%
# draw x, y plot
plt.plot(x1,y1)
plt.show()

# %%
#draw two lines in one plot
plt.plot(x1,y1,x2,y2)
plt.show()

# %% [markdown]
# ## Change line/marker style

# %%
#-g : line in green 
plt.plot(y1,'-g')

#ro- : red circle with line
plt.plot(x1,y1,'ro-')

#g* : star symbols in green
plt.plot(x1,y1,'ro-',x2,y2,'g*')
plt.show()

# %% [markdown]
# ## Define the range of the axes and add legend

# %%
plt.plot(x2, y2, color='green', linestyle='dashed', marker='o',
     markerfacecolor='blue', markersize=12,label='line1',linewidth=3)
plt.axis([2, 16, -16, 2]) # [xmin, xmax, ymin, ymax]
plt.legend()
plt.show()

# %% [markdown]
# ## Add axes title, axis label and line legend

# %%
line1 = plt.plot(x1, y1)
line2 = plt.plot(x2, y2)
plt.setp(line1, color='r', linewidth=2.0, label='mouse')
plt.setp(line2, color='b', linewidth=2.0, label='pig')
plt.title('test results', color='g',fontsize=18)
plt.xlabel('days',fontsize=16,style='italic')
plt.ylabel('value',fontsize=16,style='italic', rotation='horizontal')
plt.legend() # to show legend
plt.show()

# %%
# change the shape of the figure 
plt.figure(figsize=(8,2)) # (row, column)

line1 = plt.plot(x1, y1)
line2 = plt.plot(x2, y2)
plt.setp(line1, color='r', linewidth=2.0, label='mouse')
plt.setp(line2, color='b', linewidth=2.0, label='pig')
plt.title('test results', color='g',fontsize=18)
plt.xlabel('days',fontsize=16,style='italic')
plt.ylabel('value',fontsize=16,style='italic', rotation='horizontal')
plt.legend() # to show legend
plt.show()

# %% [markdown]
# ## Plot functions and subplots

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100)
x
# Out:
# array([-6.28318531, -6.15625227, -6.02931923, -5.9023862 , -5.77545316,
#        -5.64852012, -5.52158709, -5.39465405, -5.26772102, -5.14078798,
#        -5.01385494, -4.88692191, -4.75998887, -4.63305583, -4.5061228 ,
#        -4.37918976, -4.25225672, -4.12532369, -3.99839065, -3.87145761,
#        -3.74452458, -3.61759154, -3.4906585 , -3.36372547, -3.23679243,
#        -3.10985939, -2.98292636, -2.85599332, -2.72906028, -2.60212725,
#        -2.47519421, -2.34826118, -2.22132814, -2.0943951 , -1.96746207,
#        -1.84052903, -1.71359599, -1.58666296, -1.45972992, -1.33279688,
#        -1.20586385, -1.07893081, -0.95199777, -0.82506474, -0.6981317 ,
#        -0.57119866, -0.44426563, -0.31733259, -0.19039955, -0.06346652,
#         0.06346652,  0.19039955,  0.31733259,  0.44426563,  0.57119866,
#         0.6981317 ,  0.82506474,  0.95199777,  1.07893081,  1.20586385,
#         1.33279688,  1.45972992,  1.58666296,  1.71359599,  1.84052903,
# ...

# %%
y1 = np.cos(x)

# %%
y1
# Out:
# array([ 1.        ,  0.99195481,  0.9679487 ,  0.92836793,  0.87384938,
#         0.80527026,  0.72373404,  0.63055267,  0.52722547,  0.41541501,
#         0.29692038,  0.17364818,  0.04758192, -0.07924996, -0.20480667,
#        -0.32706796, -0.44406661, -0.55392006, -0.65486073, -0.74526445,
#        -0.82367658, -0.88883545, -0.93969262, -0.97542979, -0.99547192,
#        -0.99949654, -0.98743889, -0.95949297, -0.91610846, -0.85798341,
#        -0.78605309, -0.70147489, -0.60560969, -0.5       , -0.38634513,
#        -0.26647381, -0.14231484, -0.01586596,  0.1108382 ,  0.23575894,
#         0.35688622,  0.47227107,  0.58005691,  0.67850941,  0.76604444,
#         0.84125353,  0.90292654,  0.95007112,  0.9819287 ,  0.99798668,
#         0.99798668,  0.9819287 ,  0.95007112,  0.90292654,  0.84125353,
#         0.76604444,  0.67850941,  0.58005691,  0.47227107,  0.35688622,
#         0.23575894,  0.1108382 , -0.01586596, -0.14231484, -0.26647381,
# ...

# %%
plt.plot(x,y1, color='r', linewidth=2.0)
plt.ylabel(r'$cos(x)$', fontsize=16)
plt.show()

# %%
y2 = np.sin(x)

# %%
plt.plot(x,y2, color='b', linewidth=2.0)
plt.ylabel(r'$sin(x)$', fontsize=16)
plt.show()

# %%
# make subplots vertically 
plt.subplot(2, 1, 1)
plt.plot(x, y1, 'yo-')
plt.ylabel(r'$cos(x)$', fontsize=16)
plt.title('Two subplots')

plt.subplot(2, 1, 2)
plt.plot(x, y2, 'r.-')
plt.xlabel('radiant')
plt.ylabel(r'$sin(x)$', fontsize=16)
# Out:
# Text(0, 0.5, '$sin(x)$')

# %%
# make subplots horizontally 
plt.subplot(1, 2, 1)
plt.plot(x, y1, 'yo-')
plt.ylabel(r'$cos(x)$', fontsize=14)
plt.xlabel('radiant')

plt.subplot(1, 2, 2)
plt.plot(x, y2, 'r.-')
plt.xlabel('radiant')
plt.ylabel(r'$sin(x)$', fontsize=14)
# Out:
# Text(0, 0.5, '$sin(x)$')

# %%
# Improve subplot size/spacing with many subplots in matplotlib
plt.subplot(1, 2, 1)
plt.plot(x, y1, 'yo-')
plt.ylabel(r'$cos(x)$', fontsize=16)
plt.xlabel('radiant')

plt.subplot(1, 2, 2)
plt.plot(x, y2, 'r.-')
plt.xlabel('radiant')
plt.ylabel(r'$sin(x)$', fontsize=16)

plt.tight_layout() # make more space

# %% [markdown]
# ## Summary:
# 1. learned matplotlib and pyplot
# 2. plot lines
# 3. change line/marker style
# 4. define the range of the axes and add legend
# 5. add axes title, axis label and line legend
# 6. change the size of the figure
# 7. plot functions
# 8. make subplots
# 9. improve subplot size/spacing with many subplots in matplotlib

# %% [markdown]
# ## Next: Seaborn
