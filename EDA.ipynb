# %%
# importing Liberaries
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %% [markdown]
# " %matplotlib inline " makes life easy by returning output plots without needing to write plt.show() code everytime after each plot!

# %%
# Reading and displaying data
df = pd.read_csv('winequality-white.csv',delimiter=';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# # 1. Understand the data using the pandas library

# %% [markdown]
# ***1. Print the first five rows of the dataset***

# %%
# displaying First five rows of dataset
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# ***2. Print last 5 rows of the dataset***

# %%
# Displying last five rows of data set
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# ...

# %% [markdown]
# ***3. Find out the total number of rows and columns of the data set***

# %%
# finding the shape of the dataset
df.shape
# Out:
# (4898, 12)

# %%
# printing no. of rows and columns
print("No. of Rows in Dataset is 4898 and No. of Columns in Dataset is 12")
# Out:
# No. of Rows in Dataset is 4898 and No. of Columns in Dataset is 12

# %% [markdown]
# ***4. Find out the columns, data types, and presence of null values or missing values in the data set***

# %%
# getting the info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# # 2. Univariate Analysis

# %% [markdown]
# ***1. Find out missing values graphically***

# %%
# checking missing values

sns.heatmap(df.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %%
print("There are no Missing Values in the data")
# Out:
# There are no Missing Values in the data

# %%
# Confirmation for the Graph
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ***2. Find out the number of rows, mean, std deviation, min, Q1, Q2, Q3, max values for each variable. Document your observations to check if the outliers are present in the data set***

# %%
# Describing the data
round(df.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count         4898.0            4898.0       4898.0          4898.0
# mean             7.0               0.0          0.0             6.0
# std              1.0               0.0          0.0             5.0
# min              4.0               0.0          0.0             1.0
# 25%              6.0               0.0          0.0             2.0
# 50%              7.0               0.0          0.0             5.0
# 75%              7.0               0.0          0.0            10.0
# max             14.0               1.0          2.0            66.0
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density      pH  \
# count     4898.0               4898.0                4898.0   4898.0  4898.0
# mean         0.0                 35.0                 138.0      1.0     3.0
# std          0.0                 17.0                  42.0      0.0     0.0
# ...

# %% [markdown]
# ***3. Draw the histogram, kernel density estimate (kde) to check the distribution and skewness for each variable. Document your observation***

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['alcohol'])
plt.subplot(1,2,2)
df['alcohol'].hist(bins=20)
plt.title("Histogram and KDE Graph For ALCOHOL")
plt.tight_layout() # make more space 
plt.show()
print('The long tail is on the right side so it is Skewed Right So,[Mean > Median]')
# Out:
# The long tail is on the right side so it is Skewed Right So,[Mean > Median]

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['chlorides'])
plt.subplot(1,2,2)
df['chlorides'].hist(bins=20)
plt.title("Histogram and KDE Graph For CHLORIDES")
plt.tight_layout() # make more space 
plt.show()
print("The long tail is on the right side so it is Skewed Right So,[Mean > Median]")
# Out:
# The long tail is on the right side so it is Skewed Right So,[Mean > Median]

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['citric acid'])
plt.subplot(1,2,2)
df['citric acid'].hist(bins=20)
plt.title("Histogram and KDE Graph For CITRIC ACID")
plt.tight_layout() # make more space 
plt.show()
print("The long tail is on the right side so it is Skewed Right So,[Mean > Median]")
# Out:
# The long tail is on the right side so it is Skewed Right So,[Mean > Median]

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['density'])
plt.subplot(1,2,2)
df['density'].hist(bins=20)
plt.title("Histogram and KDE Graph For DENSITY")
plt.tight_layout() # make more space 
plt.show()
print("The long tail is on the right side so it is Skewed Right So,[Mean > Median]")
# Out:
# The long tail is on the right side so it is Skewed Right So,[Mean > Median]

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['fixed acidity'])
plt.subplot(1,2,2)
df['fixed acidity'].hist(bins=20)
plt.title("Histogram and KDE Graph For FIXED ACIDITY")
plt.tight_layout() # make more space 
plt.show()
print("The long tail is on the right side so it is Skewed Right So,[Mean > Median]")
# Out:
# The long tail is on the right side so it is Skewed Right So,[Mean > Median]

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['free sulfur dioxide'])
plt.subplot(1,2,2)
df['free sulfur dioxide'].hist(bins=20)
plt.title("Histogram and KDE Graph For FREE SULFUR DIOXIDE")
plt.tight_layout() # make more space 
plt.show()
print("The long tail is on the right side so it is Skewed Right So,[Mean > Median]")
# Out:
# The long tail is on the right side so it is Skewed Right So,[Mean > Median]

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['pH'])
plt.subplot(1,2,2)
df['pH'].hist(bins=20)
plt.title("Histogram and KDE Graph For pH")
plt.tight_layout() # make more space 
plt.show()
print("The long tail is on the right side so it is Skewed Right So,[Mean > Median]")
# Out:
# The long tail is on the right side so it is Skewed Right So,[Mean > Median]

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['quality'])
plt.subplot(1,2,2)
df['quality'].hist(bins=50)
plt.title("Histogram and KDE Graph For QUALITY")
plt.tight_layout() # make more space 
plt.show()
print("This graph does not have any skewness becouse there is no ling tail on any side. Therefore It is Unimodel/Symmetrical Histogram ")
# Out:
# This graph does not have any skewness becouse there is no ling tail on any side. Therefore It is Unimodel/Symmetrical Histogram

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['residual sugar'])
plt.subplot(1,2,2)
df['residual sugar'].hist(bins=20)
plt.title("Histogram and KDE Graph For RESIDUAL SUGAR")
plt.tight_layout() # make more space 
plt.show()
print("The long tail is on the right side so it is Skewed Right So,[Mean > Median]")
# Out:
# The long tail is on the right side so it is Skewed Right So,[Mean > Median]

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['sulphates'])
plt.subplot(1,2,2)
df['sulphates'].hist(bins=20)
plt.title("Histogram and KDE Graph For SULPHATES")
plt.tight_layout() # make more space 
plt.show()
print("The long tail is on the right side so it is Skewed Right So,[Mean > Median]")
# Out:
# The long tail is on the right side so it is Skewed Right So,[Mean > Median]

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['total sulfur dioxide'])
plt.subplot(1,2,2)
df['total sulfur dioxide'].hist(bins=20)
plt.title("Histogram and KDE Graph For TOTAL SULFUR DIOXIDE")
plt.tight_layout() # make more space 
plt.show()
print("The long tail is on the right side so it is Skewed Right So,[Mean > Median]")
# Out:
# The long tail is on the right side so it is Skewed Right So,[Mean > Median]

# %%
plt.subplot(1,2,1)
sns.kdeplot(df['volatile acidity'])
plt.subplot(1,2,2)
df['volatile acidity'].hist(bins=20)
plt.title("Histogram and KDE Graph For VOLATILE ACIDITY")
plt.tight_layout() # make more space 
plt.show()
print("The long tail is on the right side so it is Skewed Right So,[Mean > Median]")
# Out:
# The long tail is on the right side so it is Skewed Right So,[Mean > Median]

# %% [markdown]
# ***4. use subplot to make all histograms. Document your observation***

# %%
l = df.columns.values
number_of_columns=4
number_of_rows = 3

# Figure size (width, height) in inches
fig = plt.figure(figsize=(12, 4))

# Adjust the subplots 
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.5, wspace=1)

for i in range(0,len(l)):
    plt.subplot(number_of_rows,number_of_columns,i+1)
    sns.histplot(df[l[i]],kde=True) 
    plt.xlabel('')
    plt.title(l[i])

# %% [markdown]
# - "pH" column appears to be normally distributed
# - remaining all independent variables are right skewed/positively skewed.

# %% [markdown]
# ***5. Create a frequency distribution table and bar chart for the output variable***

# %%
df.info()
print(" \n Quality Column is the Output Variable because its datatype in in int64 ant the rest of columns are in float64")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
#
# ...

# %%
# Frequency Table For Quality
print("Frequency Table for Quality")
q = pd.crosstab(index=df['quality'],columns='count')
print(q)
# Out:
# Frequency Table for Quality
# col_0    count
# quality
# 3           20
# 4          163
# 5         1457
# 6         2198
# 7          880
# 8          175
# 9            5

# %% [markdown]
# - This tells us vote count of each quality score in descending order.
# - "quality" has most values concentrated in the categories 5, 6 and 7.
# - Only a few observations made for the categories 3 & 9

# %%
# Bar Graph for Quality
q.plot.bar(figsize=(10,5),rot=0)
# Out:
# <AxesSubplot:xlabel='quality'>

# %% [markdown]
# ***6. Draw box plot for each variable and identify the IQR and outliers***

# %%
print('Boxplot, IQR, qutliner for ALCOHOL')

sns.boxplot(df['alcohol'])
plt.show()

print("IQR For ALCOHOL Column : ",stats.iqr(df['alcohol'],axis=0))

print("There are no outliners in ALCOHOL columns")
# Out:
# Boxplot, IQR, qutliner for ALCOHOL
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For ALCOHOL Column :  1.9000000000000004
# There are no outliners in ALCOHOL columns

# %%
print('Boxplot, IQR, qutliner for CLHORIDES')

sns.boxplot(df['chlorides'])
plt.show()

print("IQR For CHLORIDE Column : ",stats.iqr(df['chlorides'],axis=0))

print("There are many outliners in CHLORIDE columns")
# Out:
# Boxplot, IQR, qutliner for CLHORIDES
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For CHLORIDE Column :  0.014000000000000005
# There are many outliners in CHLORIDE columns

# %%
print('Boxplot, IQR, qutliner for CITRIC ACID')

sns.boxplot(df['citric acid'])
plt.show()

print("IQR For CITRIC ACID Column : ",stats.iqr(df['citric acid'],axis=0))

print("There are many outliners in CITRIC ACID columns")
# Out:
# Boxplot, IQR, qutliner for CITRIC ACID
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For CITRIC ACID Column :  0.12
# There are many outliners in CITRIC ACID columns

# %%
print('Boxplot, IQR, qutliner for DENSITY')

sns.boxplot(df['density'])
plt.show()

print("IQR For DENSITY Column : ",stats.iqr(df['density'],axis=0))

print("There are 3 outliners in DENSITY columns")
# Out:
# Boxplot, IQR, qutliner for DENSITY
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For DENSITY Column :  0.004377499999999923
# There are 3 outliners in DENSITY columns

# %%
print('Boxplot, IQR, qutliner for FIXED ACIDITY')

sns.boxplot(df['fixed acidity'])
plt.show()

print("IQR For FIXED ACIDITY Column : ",stats.iqr(df['fixed acidity'],axis=0))

print("There are Many outliners in FIXED ACIDITY columns")
# Out:
# Boxplot, IQR, qutliner for FIXED ACIDITY
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For FIXED ACIDITY Column :  1.0
# There are Many outliners in FIXED ACIDITY columns

# %%
print('Boxplot, IQR, qutliner for FREE SULFUR DIOXIDE')

sns.boxplot(df['free sulfur dioxide'])
plt.show()

print("IQR For FREE SULFUR DIOXIDE Column : ",stats.iqr(df['free sulfur dioxide'],axis=0))

print("There are Many outliners in FREE SULFUR DIOXIDE columns")
# Out:
# Boxplot, IQR, qutliner for FREE SULFUR DIOXIDE
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For FREE SULFUR DIOXIDE Column :  23.0
# There are Many outliners in FREE SULFUR DIOXIDE columns

# %%
print('Boxplot, IQR, qutliner for pH')

sns.boxplot(df['pH'])
plt.show()

print("IQR For pH Column : ",stats.iqr(df['pH'],axis=0))

print("There are Many outliners in pH columns")
# Out:
# Boxplot, IQR, qutliner for pH
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For pH Column :  0.18999999999999995
# There are Many outliners in pH columns

# %%
print('Boxplot, IQR, qutliner for QUALITY')

sns.boxplot(df['quality'])
plt.show()

print("IQR For QUALITY Column : ",stats.iqr(df['quality'],axis=0))

print("There are 3 outliners in QUALITY columns")
# Out:
# Boxplot, IQR, qutliner for QUALITY
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For QUALITY Column :  1.0
# There are 3 outliners in QUALITY columns

# %%
print('Boxplot, IQR, qutliner for RESIDUAL SUGAR')

sns.boxplot(df['residual sugar'])
plt.show()

print("IQR For RESIDUAL SUGAR Column : ",stats.iqr(df['residual sugar'],axis=0))

print("There are 5 outliners in RESIDUAL SUGAR columns")
# Out:
# Boxplot, IQR, qutliner for RESIDUAL SUGAR
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For RESIDUAL SUGAR Column :  8.200000000000001
# There are 5 outliners in RESIDUAL SUGAR columns

# %%
print('Boxplot, IQR, qutliner for SULPHATES')

sns.boxplot(df['sulphates'])
plt.show()

print("IQR For SULPHATES Column : ",stats.iqr(df['sulphates'],axis=0))

print("There are Many outliners in SULPHATES columns")
# Out:
# Boxplot, IQR, qutliner for SULPHATES
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For SULPHATES Column :  0.14000000000000007
# There are Many outliners in SULPHATES columns

# %%
print('Boxplot, IQR, qutliner for TOTAL SULFUR DIOXIDE')

sns.boxplot(df['total sulfur dioxide'])
plt.show()

print("IQR For TOTAL SULFUR DIOXIDE Column : ",stats.iqr(df['total sulfur dioxide'],axis=0))

print("There are Many outliners in TOTAL SULFUR DIOXIDE columns")
# Out:
# Boxplot, IQR, qutliner for TOTAL SULFUR DIOXIDE
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For TOTAL SULFUR DIOXIDE Column :  59.0
# There are Many outliners in TOTAL SULFUR DIOXIDE columns

# %%
print('Boxplot, IQR, qutliner for VOLATILE ACIDITY')

sns.boxplot(df['volatile acidity'])
plt.show()

print("IQR For VOLATILE ACIDITY Column : ",stats.iqr(df['volatile acidity'],axis=0))

print("There are Many outliners in VOLATILE ACIDITY columns")
# Out:
# Boxplot, IQR, qutliner for VOLATILE ACIDITY
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# IQR For VOLATILE ACIDITY Column :  0.11000000000000001
# There are Many outliners in VOLATILE ACIDITY columns

# %% [markdown]
# ***7. Draw box plot for all variables and identify the outliers***

# %%
l = df.columns.values
number_of_columns=4
number_of_rows = 3

# Figure size (width, height) in inches
fig = plt.figure(figsize=(12, 6))

# Adjust the subplots 
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.5, wspace=1)

for i in range(0,len(l)):
    plt.subplot(number_of_rows,number_of_columns,i+1)
    sns.boxplot(data = df[l[i]])
    plt.xlabel('')
    plt.title(l[i])

# %% [markdown]
# Except "alcohol" all other features columns shows outliers.

# %% [markdown]
# # 3. Multivariate Analysis

# %% [markdown]
# ***1. Draw the correlation matrix and identify the variables that are correlated to each other.***

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(),cmap='Blues',annot=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Dark shades represents positive correlation while lighter shades represents negative correlation.
# - If you set annot=True, you'll get values by which features are correlated to each other in grid-cells

# %%
# creating Co-relation matrix
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(), annot = True,ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Here we can infer that "density" has strong positive correlation with "residual sugar" whereas it has strong negative correlation with "alcohol".
# - "free sulphur dioxide" and "citric acid" has almost no correlation with "quality"
# - Since correlation is zero we can infer there is no linear relationship between these two predictors.However it is safe to drop these features in case you're applying Linear Regression model to the dataset.

# %% [markdown]
# # 4. Modelling

# %%
sns.countplot(x='quality',data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
# converting the response variables(3-7) as binary response variables that is either good or bad

df['quality'] = df['quality'].map({3 : 'bad', 4 :'bad', 5: 'bad',
                                      6: 'good', 7: 'good', 8: 'good', 9: 'good'})

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol quality
# 4893     11.2    good
# ...

# %%
# analyzing the different values present in the dependent variable(quality column)
df['quality'].value_counts()
# Out:
# good    3258
# bad     1640
# Name: quality, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['quality'] = le.fit_transform(df['quality'])

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        1
# ...

# %%
df['quality'].nunique()
# Out:
# 2

# %%
df['quality'].unique()
# Out:
# array([1, 0])

# %%
sns.countplot(df['quality'])
# Out:
# /Users/Pi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
# dividing the dataset into dependent and independent variables

x = df.iloc[:,:11]  # predictor variable
y = df.iloc[:,11]   # target variable 

# determining the shape of x and y.
print(x.shape)
print(y.shape)
# Out:
# (4898, 11)
# (4898,)

# %%
# dividing the dataset in training and testing set

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# determining the shapes of training and testing sets
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3673, 11)
# (3673,)
# (1225, 11)
# (1225,)

# %%
# standard scaling 
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %% [markdown]
# ## use sklearn Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV, cross_val_score



# creating the model
model = LogisticRegression()

# feeding the training set into the model
model.fit(x_train, y_train)

# predicting the results for the test set
y_pred = model.predict(x_test)

# calculating the training and testing accuracies
print("Training accuracy :", model.score(x_train, y_train))
print("Testing accuracy :", model.score(x_test, y_test))
# Out:
# Training accuracy : 0.7541519194119248
# Testing accuracy : 0.7477551020408163

# %% [markdown]
# ## Evaluate your model

# %%
# classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.52      0.57       397
#            1       0.79      0.86      0.82       828
#
#     accuracy                           0.75      1225
#    macro avg       0.71      0.69      0.70      1225
# weighted avg       0.74      0.75      0.74      1225

# %%
# confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)
print(cf_matrix)
# Out:
# [[207 190]
#  [119 709]]

# %%
ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues', fmt="d")
ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted quality')
ax.set_ylabel('Actual quality ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['bad','good'])
ax.yaxis.set_ticklabels(['bad','good'])

## Display the visualization of the Confusion Matrix.
plt.show()
